# %%
import numpy as np
import pandas as pd

# %%
#dataframe --> represent the data in tabular format

emp_info = {'Id':[101,102,103],'name':['john','alex','smith'],'dept':['it','sales','finance'],'salary':[35000,40000,20000]}
print(emp_info)
# Out:
# {'Id': [101, 102, 103], 'name': ['john', 'alex', 'smith'], 'dept': ['it', 'sales', 'finance'], 'salary': [35000, 40000, 20000]}

# %%
data=pd.DataFrame(emp_info)
print(data)
print(type(data))
# Out:
#     Id   name     dept  salary
# 0  101   john       it   35000
# 1  102   alex    sales   40000
# 2  103  smith  finance   20000
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#     Id   name     dept  salary
# 0  101   john       it   35000
# 1  102   alex    sales   40000
# 2  103  smith  finance   20000

# %%
print (data.shape)
# Out:
# (3, 4)

# %%
print(data['dept'].values)
# Out:
# ['it' 'sales' 'finance']

# %%
data[['name','dept']]
# Out:
#     name     dept
# 0   john       it
# 1   alex    sales
# 2  smith  finance

# %%
#date_range()
#yyyymmdd
dates =pd.date_range('20250101',periods=10)
print(dates)
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(10,4),index=dates,columns=list('ABCD'))
print(df)
# Out:
#                    A         B         C         D
# 2025-01-01  1.257457 -1.282303  0.197140  1.258768
# 2025-01-02  1.138999  0.185430  0.037294  0.898005
# 2025-01-03 -0.111854  2.247207 -1.720320 -2.396492
# 2025-01-04 -0.506116  0.935762  1.537671  0.385084
# 2025-01-05  0.933296 -1.513773 -0.426185 -0.771421
# 2025-01-06  0.822217 -0.708185 -0.731361 -0.444889
# 2025-01-07 -0.388565  0.944053 -1.428750  1.430128
# 2025-01-08 -0.389333 -0.177674  0.414369  1.819348
# 2025-01-09 -0.929006  0.031163 -1.689319 -1.597426
# 2025-01-10 -0.002200  0.425452 -0.778003 -0.321888

# %%
data[data['salary']>1500]
# Out:
#     Id   name     dept  salary
# 0  101   john       it   35000
# 1  102   alex    sales   40000
# 2  103  smith  finance   20000

# %%
data[(data['salary'] > 25000) & (data['dept'] == 'it')]
# Out:
#     Id  name dept  salary
# 0  101  john   it   35000
