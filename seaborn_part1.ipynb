# %% [markdown]
# <a href="https://colab.research.google.com/github/mayurraj9378/Data-Science/blob/main/seaborn_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data visualization - seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
# built in datasets of seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dataset=sns.load_dataset('iris')
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#line graph --> lineplot()
sns.lineplot(x='sepal_length',y='sepal_width',data=dataset)
plt.title('Line Graph in seaborn')
plt.show()

# %%
#customize seaborn plots
sns.set_style('darkgrid',{'grid.color':'k','grid.linestyle':':'})  #linestyle -- : -
sns.lineplot(x='sepal_length',y='sepal_width',data=dataset)
plt.title('Line Graph in seaborn')
plt.show()

# %%
#change the figure size also
plt.figure(figsize=(10,5))
sns.lineplot(x='sepal_length',y='sepal_width',data=dataset)
plt.title('Line Graph in seaborn')
plt.show()

# %%
pokemon = pd.read_csv('https://raw.githubusercontent.com/yash240990/Python/master/pokemon.csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#scatter plot in seaborn
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x='Attack',y='Defense',hue='Generation',data=pokemon)
plt.show()

# %%
pokemon.Generation.value_counts().sort_index()
# Out:
# Generation
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# Name: count, dtype: int64

# %%
pokemon.Generation.value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
colors = ['r','y','b','g','c','m']
sns.scatterplot(x='Attack',y='Defense',hue='Generation',data=pokemon,palette=colors)
plt.title('Scatter Plot in seaborn')
plt.show()
