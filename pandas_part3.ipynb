# %% [markdown]
# <a href="https://colab.research.google.com/github/mayurraj9378/Data-Science/blob/main/pandas_part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# numpy : array
# pandas : series dataframe
# pandas : use pandas to  deal with diff diff file format

# %%
#using pandas to deal eith diff diff file format
#Read an excel file
#Read a csv file
#Read a txt file
#Rrad json file
#upload local files

# %%
data= pd.read_excel('https://raw.githubusercontent.com/yash240990/Python/master/sampleExcelData.xlsx')

# %%
data
# Out:
#        id first_name   last_name                      email    gender  \
# 0       1      Merle     Draisey  mdraisey0@squarespace.com  Bigender
# 1       2      Casey      Sheach    csheach1@deviantart.com      Male
# 2       3      Darya     Leivers        dleivers2@imgur.com    Female
# 3       4     Fancie  Casebourne          fcasebourne3@g.co    Female
# 4       5    Jenilee    Vsanelli         jvsanelli4@fc2.com    Female
# ..    ...        ...         ...                        ...       ...
# 995   996     Lutero       Yurov            lyurovrn@un.org      Male
# 996   997      Verla       Peery           vpeeryro@com.com    Female
# 997   998       Fran     Langran          flangranrp@ft.com      Male
# 998   999      Gabbi     Cummins        gcumminsrq@jugem.jp    Female
# 999  1000   Gloriane        Marc   gmarcrr@businessweek.com    Female
#
#           ip_address
# 0       20.70.199.51
# 1    226.126.229.167
# 2     247.209.88.235
# 3     172.34.162.239
# ...

# %%
# for accesssing diff sheet in excel

# %%
excelfile=pd.ExcelFile('https://raw.githubusercontent.com/yash240990/Python/master/sampleExcelData.xlsx')

# %%
excelfile.sheet_names
# Out:
# ['data', 'Sheet2']

# %%
data=pd.read_excel(excelfile,'Sheet2')

# %%
data
# Out:
#    first_name    last_name                                 email
# 0       Merle      Draisey             mdraisey0@squarespace.com
# 1       Casey       Sheach               csheach1@deviantart.com
# 2       Darya      Leivers                   dleivers2@imgur.com
# 3      Fancie   Casebourne                     fcasebourne3@g.co
# 4     Jenilee     Vsanelli                    jvsanelli4@fc2.com
# 5    Charmian    Drinkhall       cdrinkhall5@theglobeandmail.com
# 6     Janessa       Kivell                 jkivell6@linkedin.com
# 7       Mirna       Heinsh                  mheinsh7@spotify.com
# 8       Darby          Lax                   dlax8@people.com.cn
# 9       Meryl        Riehm                 mriehm9@princeton.edu
# 10       Anne        Brody                    abrodya@sphinn.com
# 11       Puff    Langsbury             plangsburyb@canalblog.com
# 12       Tina      Gregoli                  tgregolic@sfgate.com
# ...

# %%
# READ AN CSV format
# pandas provides method called as read_csv()
data=pd.read_csv('https://raw.githubusercontent.com/yash240990/Python/master/Position_Salaries.csv')

# %%
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
# reading a txt tab delimited format
data2=pd.read_csv('https://www.inf.ed.ac.uk/teaching/courses/inf2b/labs/iris.txt',sep='\t')

# %%
data2
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
# READING Json FIles

# %%
#read a Json  Format
data=pd.read_json('https://raw.githubusercontent.com/yash240990/Python/master/simple.json')

# %%
data
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
# upload Local files

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-cc59433d-09e8-43e3-ae19-85eb95fcb7fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc59433d-09e8-43e3-ae19-85eb95fcb7fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('MOCK_DATA.csv')
data
# Out:
#        id first_name     last_name                         email  gender  \
# 0       1       Even        Larvin       elarvin0@guardian.co.uk    Male
# 1       2   Jefferey     Devonport       jdevonport1@twitter.com    Male
# 2       3     Jobina     Fremantle           jfremantle2@tiny.cc  Female
# 3       4  Shandeigh       Cookley     scookley3@squarespace.com  Female
# 4       5      Dacia  MacConnechie       dmacconnechie4@imdb.com  Female
# ..    ...        ...           ...                           ...     ...
# 995   996       Adah         Birts  abirtsrn@merriam-webster.com  Female
# 996   997     Myrtia         Manus              mmanusro@psu.edu  Female
# 997   998      Keith      Ketteman           kkettemanrp@msn.com    Male
# 998   999   Lauraine       Cearley         lcearleyrq@toplist.cz  Female
# 999  1000      Amory       Tavener         atavenerrr@netlog.com    Male
#
#      salary
# 0     20110
# 1     37637
# 2     23240
# 3     27939
# 4     39548
# ...
